# %% [markdown]
# # Sample Analysis - a Comparison of Hot-Stints
# The following is just one way you might want to use the scripts. In this example I completed three hot-stints in identical conditions at the Hungaroring to compare three different cars (the Lamborghini Huracàn EVO2, Ferrari 296 GT3 and Mercedes AMG GT3 Evo 2020) using the default aggressive setups.

# %% [markdown]
# ## Setup

# %%
# Import libraries
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Chart sizes
chart_size_x = 12
chart_size_y = 8

# %%
# Import data from the Lamborghini stint
lamborghini = pd.read_csv("ACC-Data-2023-04-24-19-14-54.csv", index_col=0)
lamborghini = lamborghini[lamborghini["BestLapTime"] != 2147483647]
# Import data from the Ferrari stint
ferrari = pd.read_csv("ACC-Data-2023-04-24-19-31-10.csv", index_col=0)
ferrari = ferrari[ferrari["BestLapTime"] != 2147483647]
# Import data from the Mercedes stint
mercedes = pd.read_csv("ACC-Data-2023-04-24-19-57-07.csv", index_col=0)
mercedes = mercedes[mercedes["BestLapTime"] != 2147483647]

# %%
lamborghini
# Out:
#            Track                           Car CarClass  Session
# 130  hungaroring  lamborghini_huracan_gt3_evo2      gt3        7  \
# 131  hungaroring  lamborghini_huracan_gt3_evo2      gt3        7
# 132  hungaroring  lamborghini_huracan_gt3_evo2      gt3        7
# 133  hungaroring  lamborghini_huracan_gt3_evo2      gt3        7
# 134  hungaroring  lamborghini_huracan_gt3_evo2      gt3        7
# ..           ...                           ...      ...      ...
# 675  hungaroring  lamborghini_huracan_gt3_evo2      gt3        7
# 676  hungaroring  lamborghini_huracan_gt3_evo2      gt3        7
# 677  hungaroring  lamborghini_huracan_gt3_evo2      gt3        7
# 678  hungaroring  lamborghini_huracan_gt3_evo2      gt3        7
# 679  hungaroring  lamborghini_huracan_gt3_evo2      gt3        7
#
#      SessionStatus  Flag  Penalty  InPit  InPitLane  CurrentSector  ...
# 130              2     0        0      0          0              0  ...  \
# ...

# %%
ferrari
# Out:
#            Track              Car CarClass  Session  SessionStatus  Flag
# 129  hungaroring  ferrari_296_gt3      gt3        7              2     0  \
# 130  hungaroring  ferrari_296_gt3      gt3        7              2     0
# 131  hungaroring  ferrari_296_gt3      gt3        7              2     0
# 132  hungaroring  ferrari_296_gt3      gt3        7              2     0
# 133  hungaroring  ferrari_296_gt3      gt3        7              2     0
# ..           ...              ...      ...      ...            ...   ...
# 673  hungaroring  ferrari_296_gt3      gt3        7              2     0
# 674  hungaroring  ferrari_296_gt3      gt3        7              2     0
# 675  hungaroring  ferrari_296_gt3      gt3        7              2     0
# 676  hungaroring  ferrari_296_gt3      gt3        7              2     0
# 677  hungaroring  ferrari_296_gt3      gt3        7              2     0
#
#      Penalty  InPit  InPitLane  CurrentSector  ...
# ...

# %%
mercedes
# Out:
#            Track                   Car CarClass  Session  SessionStatus  Flag
# 133  hungaroring  mercedes_amg_gt3_evo      gt3        7              2     0  \
# 134  hungaroring  mercedes_amg_gt3_evo      gt3        7              2     0
# 135  hungaroring  mercedes_amg_gt3_evo      gt3        7              2     0
# 136  hungaroring  mercedes_amg_gt3_evo      gt3        7              2     0
# 137  hungaroring  mercedes_amg_gt3_evo      gt3        7              2     0
# ..           ...                   ...      ...      ...            ...   ...
# 678  hungaroring  mercedes_amg_gt3_evo      gt3        7              2     0
# 679  hungaroring  mercedes_amg_gt3_evo      gt3        7              2     0
# 680  hungaroring  mercedes_amg_gt3_evo      gt3        7              2     0
# 681  hungaroring  mercedes_amg_gt3_evo      gt3        7              2     0
# 682  hungaroring  mercedes_amg_gt3_evo      gt3        7              2     0
#
# ...

# %% [markdown]
# ## Lamborghini Stats

# %%
# Lamborghini tyre pressure deviation
x_axis = lamborghini["LapsCompleted"] + lamborghini["TrackPosition"]
target_psi = 26.5
y_axis_1, y_axis_2, y_axis_3, y_axis_4  = lamborghini["TyrePressureFrontLeft"] - target_psi, lamborghini["TyrePressureFrontRight"] - target_psi, lamborghini["TyrePressureRearLeft"] - target_psi, lamborghini["TyrePressureRearRight"] - target_psi
plt.figure(figsize=(chart_size_x,chart_size_y))
plt.ylim(-2, 2)
plt.axhline(y=0, color="black", linestyle="solid", label="Pressure Target")
plt.axhline(y=1, color="red", linestyle="--", label="Max. Pressure")
plt.axhline(y=-1, color="blue", linestyle="--", label="Min. Pressure")
plt.scatter(x_axis, y_axis_1, s=1, label="Front Left")
plt.scatter(x_axis, y_axis_2, s=1, label="Front Right")
plt.scatter(x_axis, y_axis_3, s=1, label="Rear Left")
plt.scatter(x_axis, y_axis_4, s=1, label="Rear Right")
plt.legend(loc="upper left")
plt.grid()
plt.show()

# %%
# Lamborghini tyre temperatures
x_axis = lamborghini["LapsCompleted"] + lamborghini["TrackPosition"]
y_axis_1, y_axis_2, y_axis_3, y_axis_4  = lamborghini["TyreTemperatureFrontLeft"], lamborghini["TyreTemperatureFrontRight"], lamborghini["TyreTemperatureRearLeft"], lamborghini["TyreTemperatureRearRight"]
plt.figure(figsize=(chart_size_x,chart_size_y))
plt.ylim(55, 115)
plt.axhline(y=105, color="red", linestyle="--", label="Max. Temperature")
plt.axhline(y=65, color="blue", linestyle="--", label="Min. Temperature")
plt.scatter(x_axis, y_axis_1, s=1, label="Front Left")
plt.scatter(x_axis, y_axis_2, s=1, label="Front Right")
plt.scatter(x_axis, y_axis_3, s=1, label="Rear Left")
plt.scatter(x_axis, y_axis_4, s=1, label="Rear Right")
plt.legend(loc="upper left")
plt.grid()
plt.show()

# %%
lamborghini.agg({"TyrePressureFrontLeft": ["describe"], "TyrePressureFrontRight": ["describe"], "TyrePressureRearLeft": ["describe"], "TyrePressureRearRight": ["describe"], "TyreTemperatureFrontLeft": ["describe"], "TyreTemperatureFrontRight": ["describe"], "TyreTemperatureRearLeft": ["describe"], "TyreTemperatureRearRight": ["describe"], "TrackTemperature": ["describe"], "AmbientTemperature": ["describe"]})
# Out:
#       TyrePressureFrontLeft TyrePressureFrontRight TyrePressureRearLeft
#                    describe               describe             describe
# count            550.000000             550.000000           550.000000  \
# mean              26.443855              26.586209            26.236327
# std                0.148943               0.143166             0.113843
# min               25.978000              26.198000            25.908000
# 25%               26.381250              26.504000            26.184500
# 50%               26.476500              26.604500            26.267000
# 75%               26.545000              26.693750            26.309750
# max               26.685000              26.834000            26.419000
#
#       TyrePressureRearRight TyreTemperatureFrontLeft
#                    describe                 describe
# count            550.000000               550.000000  \
# mean              26.219611                89.159035
# ...

# %% [markdown]
# ## Ferrari Stats

# %%
# Ferrari tyre pressure deviation
x_axis = ferrari["LapsCompleted"] + ferrari["TrackPosition"]
target_psi = 26.5
y_axis_1, y_axis_2, y_axis_3, y_axis_4  = ferrari["TyrePressureFrontLeft"] - target_psi, ferrari["TyrePressureFrontRight"] - target_psi, ferrari["TyrePressureRearLeft"] - target_psi, ferrari["TyrePressureRearRight"] - target_psi
plt.figure(figsize=(chart_size_x,chart_size_y))
plt.ylim(-2, 2)
plt.axhline(y=0, color="black", linestyle="solid", label="Pressure Target")
plt.axhline(y=1, color="red", linestyle="--", label="Max. Pressure")
plt.axhline(y=-1, color="blue", linestyle="--", label="Min. Pressure")
plt.scatter(x_axis, y_axis_1, s=1, label="Front Left")
plt.scatter(x_axis, y_axis_2, s=1, label="Front Right")
plt.scatter(x_axis, y_axis_3, s=1, label="Rear Left")
plt.scatter(x_axis, y_axis_4, s=1, label="Rear Right")
plt.legend(loc="upper left")
plt.grid()
plt.show()

# %%
# Ferrari tyre temperatures
x_axis = ferrari["LapsCompleted"] + ferrari["TrackPosition"]
y_axis_1, y_axis_2, y_axis_3, y_axis_4  = ferrari["TyreTemperatureFrontLeft"], ferrari["TyreTemperatureFrontRight"], ferrari["TyreTemperatureRearLeft"], ferrari["TyreTemperatureRearRight"]
plt.figure(figsize=(chart_size_x,chart_size_y))
plt.ylim(55, 115)
plt.axhline(y=105, color="red", linestyle="--", label="Max. Temperature")
plt.axhline(y=65, color="blue", linestyle="--", label="Min. Temperature")
plt.scatter(x_axis, y_axis_1, s=1, label="Front Left")
plt.scatter(x_axis, y_axis_2, s=1, label="Front Right")
plt.scatter(x_axis, y_axis_3, s=1, label="Rear Left")
plt.scatter(x_axis, y_axis_4, s=1, label="Rear Right")
plt.legend(loc="upper left")
plt.grid()
plt.show()

# %%
ferrari.agg({"TyrePressureFrontLeft": ["describe"], "TyrePressureFrontRight": ["describe"], "TyrePressureRearLeft": ["describe"], "TyrePressureRearRight": ["describe"], "TyreTemperatureFrontLeft": ["describe"], "TyreTemperatureFrontRight": ["describe"], "TyreTemperatureRearLeft": ["describe"], "TyreTemperatureRearRight": ["describe"], "TrackTemperature": ["describe"], "AmbientTemperature": ["describe"]})
# Out:
#       TyrePressureFrontLeft TyrePressureFrontRight TyrePressureRearLeft
#                    describe               describe             describe
# count            549.000000             549.000000           549.000000  \
# mean              26.458820              26.675796            26.288344
# std                0.142767               0.143965             0.093837
# min               26.061000              26.282000            25.988000
# 25%               26.370000              26.598000            26.273000
# 50%               26.485000              26.694000            26.320000
# 75%               26.544000              26.773000            26.343000
# max               26.717000              26.941000            26.392000
#
#       TyrePressureRearRight TyreTemperatureFrontLeft
#                    describe                 describe
# count            549.000000               549.000000  \
# mean              26.379475                91.398592
# ...

# %% [markdown]
# ## Mercedes Stats

# %%
# Mercedes tyre pressure deviation
x_axis = mercedes["LapsCompleted"] + mercedes["TrackPosition"]
target_psi = 26.5
y_axis_1, y_axis_2, y_axis_3, y_axis_4  = mercedes["TyrePressureFrontLeft"] - target_psi, mercedes["TyrePressureFrontRight"] - target_psi, mercedes["TyrePressureRearLeft"] - target_psi, mercedes["TyrePressureRearRight"] - target_psi
plt.figure(figsize=(chart_size_x,chart_size_y))
plt.ylim(-2, 2)
plt.axhline(y=0, color="black", linestyle="solid", label="Pressure Target")
plt.axhline(y=1, color="red", linestyle="--", label="Max. Pressure")
plt.axhline(y=-1, color="blue", linestyle="--", label="Min. Pressure")
plt.scatter(x_axis, y_axis_1, s=1, label="Front Left")
plt.scatter(x_axis, y_axis_2, s=1, label="Front Right")
plt.scatter(x_axis, y_axis_3, s=1, label="Rear Left")
plt.scatter(x_axis, y_axis_4, s=1, label="Rear Right")
plt.legend(loc="upper left")
plt.grid()
plt.show()

# %%
# Mercedes tyre temperatures
x_axis = mercedes["LapsCompleted"] + mercedes["TrackPosition"]
y_axis_1, y_axis_2, y_axis_3, y_axis_4  = mercedes["TyreTemperatureFrontLeft"], mercedes["TyreTemperatureFrontRight"], mercedes["TyreTemperatureRearLeft"], mercedes["TyreTemperatureRearRight"]
plt.figure(figsize=(chart_size_x,chart_size_y))
plt.ylim(55, 115)
plt.axhline(y=105, color="red", linestyle="--", label="Max. Temperature")
plt.axhline(y=65, color="blue", linestyle="--", label="Min. Temperature")
plt.scatter(x_axis, y_axis_1, s=1, label="Front Left")
plt.scatter(x_axis, y_axis_2, s=1, label="Front Right")
plt.scatter(x_axis, y_axis_3, s=1, label="Rear Left")
plt.scatter(x_axis, y_axis_4, s=1, label="Rear Right")
plt.legend(loc="upper left")
plt.grid()
plt.show()

# %%
mercedes.agg({"TyrePressureFrontLeft": ["describe"], "TyrePressureFrontRight": ["describe"], "TyrePressureRearLeft": ["describe"], "TyrePressureRearRight": ["describe"], "TyreTemperatureFrontLeft": ["describe"], "TyreTemperatureFrontRight": ["describe"], "TyreTemperatureRearLeft": ["describe"], "TyreTemperatureRearRight": ["describe"], "TrackTemperature": ["describe"], "AmbientTemperature": ["describe"]})
# Out:
#       TyrePressureFrontLeft TyrePressureFrontRight TyrePressureRearLeft
#                    describe               describe             describe
# count            550.000000             550.000000           550.000000  \
# mean              26.592660              26.707760            26.227305
# std                0.178561               0.144876             0.110638
# min               26.022000              26.286000            25.997000
# 25%               26.547250              26.636250            26.176250
# 50%               26.636000              26.733500            26.221500
# 75%               26.692000              26.796000            26.268750
# max               26.877000              27.026000            26.565000
#
#       TyrePressureRearRight TyreTemperatureFrontLeft
#                    describe                 describe
# count            550.000000               550.000000  \
# mean              26.317113                93.833902
# ...

# %% [markdown]
# ## Laptime Comparison

# %%
lamborghini_laps = lamborghini.drop_duplicates(subset="LapsCompleted")
ferrari_laps = ferrari.drop_duplicates(subset="LapsCompleted")
mercedes_laps = mercedes.drop_duplicates(subset="LapsCompleted")

# %%
lamborghini_laps
# Out:
#            Track                           Car CarClass  Session
# 130  hungaroring  lamborghini_huracan_gt3_evo2      gt3        7  \
# 131  hungaroring  lamborghini_huracan_gt3_evo2      gt3        7
# 132  hungaroring  lamborghini_huracan_gt3_evo2      gt3        7
# 133  hungaroring  lamborghini_huracan_gt3_evo2      gt3        7
# 134  hungaroring  lamborghini_huracan_gt3_evo2      gt3        7
# ..           ...                           ...      ...      ...
# 675  hungaroring  lamborghini_huracan_gt3_evo2      gt3        7
# 676  hungaroring  lamborghini_huracan_gt3_evo2      gt3        7
# 677  hungaroring  lamborghini_huracan_gt3_evo2      gt3        7
# 678  hungaroring  lamborghini_huracan_gt3_evo2      gt3        7
# 679  hungaroring  lamborghini_huracan_gt3_evo2      gt3        7
#
#      SessionStatus  Flag  Penalty  InPit  InPitLane  CurrentSector  ...
# 130              2     0        0      0          0              0  ...  \
# ...

# %%
ferrari_laps
# Out:
#            Track              Car CarClass  Session  SessionStatus  Flag
# 129  hungaroring  ferrari_296_gt3      gt3        7              2     0  \
# 130  hungaroring  ferrari_296_gt3      gt3        7              2     0
# 131  hungaroring  ferrari_296_gt3      gt3        7              2     0
# 132  hungaroring  ferrari_296_gt3      gt3        7              2     0
# 133  hungaroring  ferrari_296_gt3      gt3        7              2     0
# ..           ...              ...      ...      ...            ...   ...
# 673  hungaroring  ferrari_296_gt3      gt3        7              2     0
# 674  hungaroring  ferrari_296_gt3      gt3        7              2     0
# 675  hungaroring  ferrari_296_gt3      gt3        7              2     0
# 676  hungaroring  ferrari_296_gt3      gt3        7              2     0
# 677  hungaroring  ferrari_296_gt3      gt3        7              2     0
#
#      Penalty  InPit  InPitLane  CurrentSector  ...
# ...

# %%
mercedes_laps
# Out:
#            Track                   Car CarClass  Session  SessionStatus  Flag
# 133  hungaroring  mercedes_amg_gt3_evo      gt3        7              2     0  \
# 134  hungaroring  mercedes_amg_gt3_evo      gt3        7              2     0
# 135  hungaroring  mercedes_amg_gt3_evo      gt3        7              2     0
# 136  hungaroring  mercedes_amg_gt3_evo      gt3        7              2     0
# 137  hungaroring  mercedes_amg_gt3_evo      gt3        7              2     0
# ..           ...                   ...      ...      ...            ...   ...
# 678  hungaroring  mercedes_amg_gt3_evo      gt3        7              2     0
# 679  hungaroring  mercedes_amg_gt3_evo      gt3        7              2     0
# 680  hungaroring  mercedes_amg_gt3_evo      gt3        7              2     0
# 681  hungaroring  mercedes_amg_gt3_evo      gt3        7              2     0
# 682  hungaroring  mercedes_amg_gt3_evo      gt3        7              2     0
#
# ...

# %%
lamborghini_laps.agg({"LastLapTime": ["describe"]})
# Out:
#          LastLapTime
#             describe
# count       6.000000
# mean   109723.333333
# std       634.588581
# min    109115.000000
# 25%    109293.250000
# 50%    109557.000000
# 75%    109952.000000
# max    110822.000000

# %%
ferrari_laps.agg({"LastLapTime": ["describe"]})
# Out:
#          LastLapTime
#             describe
# count       6.000000
# mean   109376.000000
# std       439.303084
# min    108957.000000
# 25%    109075.250000
# 50%    109208.500000
# 75%    109645.500000
# max    110060.000000

# %%
mercedes_laps.agg({"LastLapTime": ["describe"]})
# Out:
#          LastLapTime
#             describe
# count       6.000000
# mean   109952.666667
# std       682.764869
# min    109372.000000
# 25%    109431.500000
# 50%    109787.500000
# 75%    110171.250000
# max    111157.000000
